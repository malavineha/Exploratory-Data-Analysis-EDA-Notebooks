# %% [markdown]
# ## **Operations on Dummy data**

# %%
import pandas as pd

# %%
Data={'Name':['Neha','Kavita','Priti','Ramesh','Suresh','Sushant','Ram','Raj','Sham','Radha'],
      'Age':[20,21,30,35,14,25,20,19,18,22],
      'Gender':['Female','Female','Female','Male','Male','Male','Male','Male','Male','Female'],
      'Salary':[40000,50000,60000,20000,122000,30000,56000,41000,20000,210000]
      }

# %%
# 1. Created a Data Frame (df)
df1=pd.DataFrame(Data)
df1
# Out:
#       Name  Age  Gender  Salary
# 0     Neha   20  Female   40000
# 1   Kavita   21  Female   50000
# 2    Priti   30  Female   60000
# 3   Ramesh   35    Male   20000
# 4   Suresh   14    Male  122000
# 5  Sushant   25    Male   30000
# 6      Ram   20    Male   56000
# 7      Raj   19    Male   41000
# 8     Sham   18    Male   20000
# 9    Radha   22  Female  210000

# %%
# 2. Find shape of the df
df1.shape
# Out:
# (10, 4)

# %%
# 3. Find size of the df.
df1.size
# Out:
# 40

# %%
# 4. Find dimensions of the df
df1.ndim
# Out:
# 2

# %%
# 5. List all the columns in the df
df1.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
# 6.  Find datatype of each column in the df
df1.dtypes
# Out:
# Name      object
# Age        int64
# Gender    object
# Salary     int64
# dtype: object

# %%
# 7.Find axes of the df.
df1.axes
# Out:
# [RangeIndex(start=0, stop=10, step=1),
#  Index(['Name', 'Age', 'Gender', 'Salary'], dtype='object')]

# %%
# 8. Find index of the df.
df1.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# 9. Find all values of df
df1.values
# Out:
# array([['Neha', 20, 'Female', 40000],
#        ['Kavita', 21, 'Female', 50000],
#        ['Priti', 30, 'Female', 60000],
#        ['Ramesh', 35, 'Male', 20000],
#        ['Suresh', 14, 'Male', 122000],
#        ['Sushant', 25, 'Male', 30000],
#        ['Ram', 20, 'Male', 56000],
#        ['Raj', 19, 'Male', 41000],
#        ['Sham', 18, 'Male', 20000],
#        ['Radha', 22, 'Female', 210000]], dtype=object)

# %%
# 10. Check whether the df is empty.
df1.empty
# Out:
# False

# %%
# 11.Transpose the df
df1.T
# Out:
#              0       1       2       3       4        5      6      7      8  \
# Name      Neha  Kavita   Priti  Ramesh  Suresh  Sushant    Ram    Raj   Sham
# Age         20      21      30      35      14       25     20     19     18
# Gender  Female  Female  Female    Male    Male     Male   Male   Male   Male
# Salary   40000   50000   60000   20000  122000    30000  56000  41000  20000
#
#              9
# Name     Radha
# Age         22
# Gender  Female
# Salary  210000

# %%
# 12. Find detailed information about the df
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   Gender  10 non-null     object
#  3   Salary  10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 448.0+ bytes

# %%
# 13. Display (first) top ‘n’ records from the df.
df1.head(3)
# Out:
#      Name  Age  Gender  Salary
# 0    Neha   20  Female   40000
# 1  Kavita   21  Female   50000
# 2   Priti   30  Female   60000

# %%
 # 14. Display (last) bottom ‘n’ records from the df.
 df1.tail(3)
# Out:
#     Name  Age  Gender  Salary
# 7    Raj   19    Male   41000
# 8   Sham   18    Male   20000
# 9  Radha   22  Female  210000

# %%
# 15. Display descriptive statistics for numerical columns from the df
df1.describe()
# Out:
#              Age         Salary
# count  10.000000      10.000000
# mean   22.400000   64900.000000
# std     6.131884   58765.919829
# min    14.000000   20000.000000
# 25%    19.250000   32500.000000
# 50%    20.500000   45500.000000
# 75%    24.250000   59000.000000
# max    35.000000  210000.000000

# %%
# 16. Find mean, median, mode, standard deviation values for numerical columns in df.
df1.describe().T
# Out:
#         count     mean           std      min       25%      50%       75%  \
# Age      10.0     22.4      6.131884     14.0     19.25     20.5     24.25
# Salary   10.0  64900.0  58765.919829  20000.0  32500.00  45500.0  59000.00
#
#              max
# Age         35.0
# Salary  210000.0

# %%
# 17. Return a random sample from df.
df1.sample(3)
# Out:
#     Name  Age  Gender  Salary
# 8   Sham   18    Male   20000
# 9  Radha   22  Female  210000
# 6    Ram   20    Male   56000

# %%
# 18. Find the unique values for the categorical columns in the df.
df1['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# 19. Find the number of unique values for categorical columns in df.
df1['Gender'].nunique()
# Out:
# 2

# %%
# 20. Locate first row in the df using loc.
df1.loc[0]
# Out:
# Name        Neha
# Age           20
# Gender    Female
# Salary     40000
# Name: 0, dtype: object

# %%
# 21. Locate nth row in the df using loc.
df1.loc[3]
# Out:
# Name      Ramesh
# Age           35
# Gender      Male
# Salary     20000
# Name: 3, dtype: object

# %%
# 22.Locate last row in the df using loc
df1.loc[9]
# Out:
# Name       Radha
# Age           22
# Gender    Female
# Salary    210000
# Name: 9, dtype: object

# %%
# 23. Locate all values in a range in df using loc
df1.loc[0:3]
# Out:
#      Name  Age  Gender  Salary
# 0    Neha   20  Female   40000
# 1  Kavita   21  Female   50000
# 2   Priti   30  Female   60000
# 3  Ramesh   35    Male   20000

# %%
# 24. Locate all the rows in df with specific criteria using loc.
df1.loc[df1['Age']>20]
# Out:
#       Name  Age  Gender  Salary
# 1   Kavita   21  Female   50000
# 2    Priti   30  Female   60000
# 3   Ramesh   35    Male   20000
# 5  Sushant   25    Male   30000
# 9    Radha   22  Female  210000

# %%
# 25. Locate all the rows in df with specific criteria with logical and operator using loc.
df1.loc[(df1['Age']>20) & (df1['Gender']=='Female')]
# Out:
#      Name  Age  Gender  Salary
# 1  Kavita   21  Female   50000
# 2   Priti   30  Female   60000
# 9   Radha   22  Female  210000

# %%
# 26. Locate first row in the df using iloc.
df1.iloc[0]
# Out:
# Name        Neha
# Age           20
# Gender    Female
# Salary     40000
# Name: 0, dtype: object

# %%
# 27. Locate nth row in the df using iloc.
df1.iloc[3]
# Out:
# Name      Ramesh
# Age           35
# Gender      Male
# Salary     20000
# Name: 3, dtype: object

# %%
# 28. Locate last row in the df using iloc
df1.iloc[-1]
# Out:
# Name       Radha
# Age           22
# Gender    Female
# Salary    210000
# Name: 9, dtype: object

# %%
# 29. Locate first, nth, last column in df using iloc.
df1.iloc[:,[0,3]]
# Out:
#       Name  Salary
# 0     Neha   40000
# 1   Kavita   50000
# 2    Priti   60000
# 3   Ramesh   20000
# 4   Suresh  122000
# 5  Sushant   30000
# 6      Ram   56000
# 7      Raj   41000
# 8     Sham   20000
# 9    Radha  210000

# %%
# 30. Locate all the rows in df within a specific range of row index using iloc.
df1.iloc[0:3]
# Out:
#      Name  Age  Gender  Salary
# 0    Neha   20  Female   40000
# 1  Kavita   21  Female   50000
# 2   Priti   30  Female   60000

# %%
# 31. Locate all columns within a range of column index using iloc.
df1.iloc[:,0:3]
# Out:
#       Name  Age  Gender
# 0     Neha   20  Female
# 1   Kavita   21  Female
# 2    Priti   30  Female
# 3   Ramesh   35    Male
# 4   Suresh   14    Male
# 5  Sushant   25    Male
# 6      Ram   20    Male
# 7      Raj   19    Male
# 8     Sham   18    Male
# 9    Radha   22  Female

# %%
# 32. Locate Second through third rows and first 2 columns using iloc.
df1.iloc[1:3,0:2]
# Out:
#      Name  Age
# 1  Kavita   21
# 2   Priti   30

# %%
# 33. Locate 1st and 6th rows and 1st and 4th columns using iloc.
df1.iloc[[0,5],[0,3]]
# Out:
#       Name  Salary
# 0     Neha   40000
# 5  Sushant   30000

# %% [markdown]
# ## **operations on Titanic dataset**

# %%
import pandas as pd

# %%
# 1. Created a Data Frame (df)
df1 =pd.read_excel('Titanic-Dataset.xlsx')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2. Find shape of the df1
df1.shape
# Out:
# (891, 12)

# %%
# 3. Find size of the df1
df1.size
# Out:
# 10692

# %%
# 4. Find dimensions of the df1
df1.ndim
# Out:
# 2

# %%
# 5. List all the columns in the df1
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 6. Find datatype of each column in the df1
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# 7. Find axes of the df1
df1.axes
# Out:
# [RangeIndex(start=0, stop=891, step=1),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
# 8. Find index of the df1
df1.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# 9. Find all values of df1
df1.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
# 10. Check whether the df1 is empty
df1.empty
# Out:
# False

# %%
# 11. Transpose the df1
df1.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
# 12. Find detailed information about the df1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 13. Display (first) top ‘n’ records from the df1
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 14. Display (last) bottom ‘n’ records from the df1
df1.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 15. Display descriptive statistics for numerical columns from the df1
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 16. Find mean, median, mode, standard deviation values for numerical columns in df1
df1.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
# 17. Return a random sample from df1
df1.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 562          563         0       2             Norman, Mr. Robert Douglas
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 44            45         1       3          Devaney, Miss. Margaret Delia
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 562    male  28.0      0      0    218629   13.5000              NaN        S
# 742  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 44   female  19.0      0      0    330958    7.8792              NaN        Q

# %%
# 18. Find the unique values for the categorical columns in the df1
df1['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# 19. Find the number of unique values for categorical columns in df1
df1['Sex'].nunique()
# Out:
# 2

# %%
# 20. Locate first row in the df1 using loc.
df1.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# 21. Locate nth row in the df1 using loc.
df1.loc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
# 22. Locate last row in the df1 using loc.
df1.loc[886]
# Out:
# PassengerId                      887
# Survived                           0
# Pclass                             2
# Name           Montvila, Rev. Juozas
# Sex                             male
# Age                             27.0
# SibSp                              0
# Parch                              0
# Ticket                        211536
# Fare                            13.0
# Cabin                            NaN
# Embarked                           S
# Name: 886, dtype: object

# %%
# 23. Locate all values in a range in df1 using loc.
df1.loc[0:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# 24. Locate all the rows in df1 with specific criteria using loc.
df1.loc[df1['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# 25. Locate all the rows in df1 with specific criteria with logical and operator using loc.
df1.loc[(df1['Sex']=='male') & (df1['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
# 26. Locate first row in the df1 using iloc.
df1.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# 27. Locate nth row in the df1 using iloc.
df1.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
# 28. Locate last row in the df1 using iloc.
df1.iloc[-1]
# Out:
# PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                           32.0
# SibSp                            0
# Parch                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Name: 890, dtype: object

# %%
# 29. Locate first, nth, last column in df1 using iloc.
df1.iloc[:,[0,3]]
# Out:
#      PassengerId                                               Name
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
# 30. Locate all the rows in df1 within a specific range of row index using iloc.
df1.iloc[0:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 31. Locate all columns within a range of column index using iloc.
df1.iloc[:,0:3]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
# 32. Locate Second through third rows and first 2 columns using iloc.
df1.iloc[1:3,0:2]
# Out:
#    PassengerId  Survived
# 1            2         1
# 2            3         1

# %%
# 33. Locate 1st and 6th rows and 1st and 4th columns using iloc.
df1.iloc[[0,5],[0,3]]
# Out:
#    PassengerId                     Name
# 0            1  Braund, Mr. Owen Harris
# 5            6         Moran, Mr. James
